# %%
import json
from algorithm.classic import Algorithm as Clas
from algorithm.karcas import Algorithm
import os
import time

# %% [markdown]
# функции для тестрирования работы алгоритмов

# %%
N = 100

def test_on_result(algorithm: Algorithm, filename: str):
    with open(f"results/result/{filename}.txt", "w") as file:
        for i in range(4, N + 1):
            name = f"tests/result/test_{i}.json"
            print(f"test {i}, result")
            with open(name, "r") as json_file:
                data = json.load(json_file)
                algo = algorithm
                algo.init_graph(data["num_vertex"], data["edges"])
                sum_1 = 0
                for edge in algo.search_hamilton_cycle():
                    sum_1 += edge["weight"]
                file.write(f"{sum_1}\n")
                # print(f"test,{i}, {filename}, {sum_1}")

def test_on_search(algorithm: Algorithm, filename: str):
    with open(f"results/search/{filename}.txt", "w") as file:
        k = 0
        for i in range(4, N + 1):
            name = f"tests/search/test_{i}.json"
            print(f"test {i}, search")
            with open(name, "r") as json_file:
                data = json.load(json_file)
                algo = algorithm
                algo.init_graph(data["num_vertex"], data["edges"])
                way = algo.search_hamilton_cycle()
                if len(way) != 0: k += 1 
                
        file.write(f"{k/N * 100}\n")
        
def test_on_time(algorithm: Algorithm, filename: str):
    with open(f"results/time/{filename}.txt", "w") as file:
        for i in range(4, N + 1):
            name = f"tests/time/test_{i}.json"
            print(f"test {i}, time")
            with open(name, "r") as json_file:
                data = json.load(json_file)
                algo = algorithm
                time_start = time.time()
                algo.init_graph(data["num_vertex"], data["edges"])
                way = algo.search_hamilton_cycle()
                time_end = time.time()
                if len(way) != 0: file.write(f"{time_end - time_start}\n")

def start_test(algorithm: Algorithm, filename: str, test):
    test(algorithm, filename)
    print(f"{filename} has completed successfully, {test.__name__}")
    
tests = {"result": test_on_result, "search": test_on_search, "time": test_on_time}

# %%
start_test(Clas(), "simulated_annealing", tests["result"])
# Out:
# test 4, result
# test 5, result
# test 6, result
# test 7, result
# test 8, result
# test 9, result
# test 10, result
# test 11, result
# test 12, result
# test 13, result
# test 14, result
# test 15, result
# test 16, result
# test 17, result
# test 18, result
# test 19, result
# test 20, result
# test 21, result
# test 22, result
# test 23, result
# test 24, result
# test 25, result
# test 26, result
# test 27, result
# test 28, result
# test 29, result
# test 30, result
# test 31, result
# test 32, result
# test 33, result
# test 34, result
# test 35, result
# test 36, result
# test 37, result
# test 38, result
# test 39, result
# test 40, result
# test 41, result
# test 42, result
# test 43, result
# test 44, result
# test 45, result
# test 46, result
# test 47, result
# test 48, result
# test 49, result
# test 50, result
# test 51, result
# test 52, result
# test 53, result
# test 54, result
# test 55, result
# test 56, result
# test 57, result
# test 58, result
# test 59, result
# test 60, result
# test 61, result
# test 62, result
# test 63, result
# test 64, result
# test 65, result
# test 66, result
# test 67, result
# test 68, result
# test 69, result
# test 70, result
# test 71, result
# test 72, result
# test 73, result
# test 74, result
# test 75, result
# test 76, result
# test 77, result
# test 78, result
# test 79, result
# test 80, result
# test 81, result
# test 82, result
# test 83, result
# test 84, result
# test 85, result
# test 86, result
# test 87, result
# test 88, result
# test 89, result
# test 90, result
# test 91, result
# test 92, result
# test 93, result
# test 94, result
# test 95, result
# test 96, result
# test 97, result
# test 98, result
# test 99, result
# test 100, result
# sumulated_annealing_mod_population has completed successfully, test_on_result
# test 4, result
# test 5, result
# test 6, result
# test 7, result
# test 8, result
# test 9, result
# test 10, result
# test 11, result
# test 12, result
# test 13, result
# test 14, result
# test 15, result
# test 16, result
# test 17, result
# test 18, result
# test 19, result
# test 20, result
# test 21, result
# test 22, result
# test 23, result
# test 24, result
# test 25, result
# test 26, result
# test 27, result
# test 28, result
# test 29, result
# test 30, result
# test 31, result
# test 32, result
# test 33, result
# test 34, result
# test 35, result
# test 36, result
# test 37, result
# test 38, result
# test 39, result
# test 40, result
# test 41, result
# test 42, result
# test 43, result
# test 44, result
# test 45, result
# test 46, result
# test 47, result
# test 48, result
# test 49, result
# test 50, result
# test 51, result
# test 52, result
# test 53, result
# test 54, result
# test 55, result
# test 56, result
# test 57, result
# test 58, result
# test 59, result
# test 60, result
# test 61, result
# test 62, result
# test 63, result
# test 64, result
# test 65, result
# test 66, result
# test 67, result
# test 68, result
# test 69, result
# test 70, result
# test 71, result
# test 72, result
# test 73, result
# test 74, result
# test 75, result
# test 76, result
# test 77, result
# test 78, result
# test 79, result
# test 80, result
# test 81, result
# test 82, result
# test 83, result
# test 84, result
# test 85, result
# test 86, result
# test 87, result
# test 88, result
# test 89, result
# test 90, result
# test 91, result
# test 92, result
# test 93, result
# test 94, result
# test 95, result
# test 96, result
# test 97, result
# test 98, result
# test 99, result
# test 100, result
# nearest_neibhor_population has completed successfully, test_on_result
